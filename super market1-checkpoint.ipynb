# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mar=pd.read_csv('super_market.csv')
mar
# Out:
#     days  Bread  Eggs  Potatoes  Total Revenue
# 0      1     12     5         1            150
# 1      2      6     2         2             50
# 2      3      8     3         4             75
# 3      4      6     2         1             70
# 4      5      4     1         1             39
# ..   ...    ...   ...       ...            ...
# 70    71      5     1         3             50
# 71    72      9     3         1             99
# 72    73      3     1         2             45
# 73    74      9     3         4            100
# 74    75      5     2         3             61
#
# [75 rows x 5 columns]

# %%
mar.info
# Out:
# <bound method DataFrame.info of     days  Bread  Eggs  Potatoes  Total Revenue
# 0      1     12     5         1            150
# 1      2      6     2         2             50
# 2      3      8     3         4             75
# 3      4      6     2         1             70
# 4      5      4     1         1             39
# ..   ...    ...   ...       ...            ...
# 70    71      5     1         3             50
# 71    72      9     3         1             99
# 72    73      3     1         2             45
# 73    74      9     3         4            100
# 74    75      5     2         3             61
#
# [75 rows x 5 columns]>

# %%
mar.plot('days', y='Bread')
plt.title("super_market")
plt.show()

# %%
mar.plot('days', y='Eggs')
plt.title("super_market")
plt.show()

# %%
mar.plot('days', y='Potatoes')
plt.title("super_market")
plt.show()
